# %%
from bs4 import BeautifulSoup

from urllib.request import urlopen as uReq

import time

import re

import requests

import os



def getID(review):

    links_container = review.find("a",{"class":"biz-name js-analytics-click"})

    link = links_container.get('href',' ')

    urlName=re.findall('((?<=\/)[^\/?]*(?=[^\/]*$))',link)

    ID=urlName

 

    return ID

def reviewCount(review):

    count=0 # initialize critic and text 

    countChunk=review.find('span',{'class':re.compile('review-count.rating-qualifier')})

    if countChunk: count=countChunk.text#.encode('ascii','ignore')

    count=count.replace("reviews","")

    

    return count



def getHTML(ReviewID,Count):

    check=str(ReviewID).strip("['")

    check=check.strip("']")

    if not os.path.exists('/Volumes/Khushali Harddisk/American/' + check):

                os.makedirs('/Volumes/Khushali Harddisk/American/' + check)

    os.chdir('/Volumes/Khushali Harddisk/American/' + check)

    y=0

    p=0

    while y <= int(Count) or y <= 40:

        

        my_url = 'https://www.yelp.com/biz/' +check +'?start='+str(y)

        print(my_url)

        y = y + 20

            #Opening a connection and grabbing the page

        uClient = uReq(my_url)

        page_html = uClient.read()

        uClient.close()

        

            #Parse the page as an HTML

        page_soup = BeautifulSoup(page_html.decode('ascii', 'ignore'),'lxml') 

            

        file = open('reviews_' + str(p) + ".html",'w')

        file.write(str(page_soup))

        p = p + 1  

        file.close

    return "success"



def run(url):



    pageNum=30# number of pages to collect



    

    

    for p in range(1,pageNum+1): # for each page 



        print ('page',p)

        html=None

        k=p*10

        if k==10: pageLink=url # url for page 1

        else: pageLink=url+'&start='+str(k) # make the page url

		

        for i in range(5): # try 5 times

            try:

                #use the browser to access the url

                response=requests.get(pageLink,headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36', })

                html=response.content # get the html

                break # we got the file, break the loop

            except Exception as e:# browser.open() threw an exception, the attempt to get the response failed

                print ('failed attempt',i)

                time.sleep(2) # wait 2 secs

				

		

        if not html:continue # couldnt get the page, ignore

        

        soup = BeautifulSoup(html.decode('ascii', 'ignore'),'lxml') # parse the html 

        reviews=soup.findAll('div',{'class':re.compile('search-result.natural-search-result')})

        sumReviews=0

        

        for review in reviews:  

            

        

            ReviewID=getID(review)

            Count = reviewCount(review)

            sumReviews=sumReviews+int(Count)

            getHTML(ReviewID,Count)

            

        print(sumReviews)

            

            



  



if __name__=='__main__':

    url='https://www.yelp.com/search?find_desc=American&find_loc=Los+Angeles,+CA'

    run(url)
# Out:
# page 2
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=0
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=20
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=40
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=60
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=80
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=100
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=120
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=140
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=160
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=180
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=200
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=220
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=240
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=260
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=280
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=300
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=320
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=340
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=360
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=380
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=400
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=420
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=440
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=460
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=480
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=500
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=520
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=540
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=560
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=580
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=600
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=620
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=640
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=660
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=680
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=700
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=720
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=740
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=760
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=780
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=800
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=820
# https://www.yelp.com/biz/plan-check-fairfax-los-angeles?start=840
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=0
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=20
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=40
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=60
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=80
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=100
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=120
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=140
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=160
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=180
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=200
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=220
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=240
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=260
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=280
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=300
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=320
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=340
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=360
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=380
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=400
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=420
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=440
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=460
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=480
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=500
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=520
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=540
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=560
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=580
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=600
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=620
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=640
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=660
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=680
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=700
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=720
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=740
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=760
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=780
# https://www.yelp.com/biz/preux-and-proper-los-angeles?start=800
# https://www.yelp.com/biz/fundamental-dtla-los-angeles-7?start=0
# https://www.yelp.com/biz/fundamental-dtla-los-angeles-7?start=20
# https://www.yelp.com/biz/fundamental-dtla-los-angeles-7?start=40
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=0
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=20
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=40
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=60
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=80
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=100
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=120
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=140
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=160
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=180
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=200
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=220
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=240
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=260
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=280
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=300
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=320
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=340
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=360
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=380
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=400
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=420
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=440
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=460
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=480
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=500
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=520
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=540
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=560
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=580
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=600
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=620
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=640
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=660
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=680
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=700
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=720
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=740
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=760
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=780
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=800
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=820
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=840
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=860
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=880
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=900
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=920
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=940
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=960
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=980
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1000
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1020
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1040
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1060
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1080
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1100
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1120
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1140
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1160
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1180
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1200
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1220
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1240
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1260
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1280
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1300
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1320
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1340
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1360
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1380
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1400
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1420
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1440
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1460
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1480
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1500
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1520
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1540
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1560
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1580
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1600
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1620
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1640
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1660
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1680
# https://www.yelp.com/biz/stout-burgers-and-beers-los-angeles?start=1700
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=0
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=20
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=40
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=60
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=80
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=100
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=120
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=140
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=160
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=180
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=200
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=220
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=240
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=260
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=280
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=300
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=320
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=340
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=360
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=380
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=400
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=420
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=440
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=460
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=480
# https://www.yelp.com/biz/hach%C3%A9-la-los-angeles-2?start=500
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=0
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=20
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=40
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=60
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=80
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=100
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=120
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=140
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=160
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=180
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=200
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=220
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=240
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=260
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=280
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=300
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=320
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=340
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=360
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=380
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=400
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=420
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=440
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=460
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=480
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=500
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=520
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=540
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=560
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=580
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=600
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=620
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=640
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=660
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=680
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=700
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=720
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=740
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=760
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=780
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=800
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=820
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=840
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=860
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=880
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=900
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=920
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=940
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=960
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=980
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1000
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1020
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1040
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1060
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1080
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1100
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1120
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1140
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1160
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1180
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1200
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1220
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1240
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1260
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1280
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1300
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1320
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1340
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1360
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1380
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1400
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1420
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1440
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1460
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1480
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1500
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1520
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1540
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1560
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1580
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1600
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1620
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1640
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1660
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1680
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1700
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1720
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1740
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1760
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1780
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1800
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1820
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1840
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1860
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1880
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1900
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1920
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1940
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1960
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=1980
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2000
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2020
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2040
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2060
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2080
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2100
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2120
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2140
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2160
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2180
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2200
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2220
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2240
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2260
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2280
# https://www.yelp.com/biz/plan-check-kitchen-bar-los-angeles-7?start=2300
# https://www.yelp.com/biz/the-parker-room-los-angeles?start=0
# https://www.yelp.com/biz/the-parker-room-los-angeles?start=20
# https://www.yelp.com/biz/the-parker-room-los-angeles?start=40
# https://www.yelp.com/biz/the-parker-room-los-angeles?start=60
# https://www.yelp.com/biz/the-parker-room-los-angeles?start=80
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=0
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=20
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=40
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=60
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=80
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=100
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=120
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=140
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=160
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=180
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=200
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=220
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=240
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=260
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=280
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=300
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=320
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=340
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=360
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=380
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=400
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=420
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=440
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=460
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=480
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=500
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=520
# https://www.yelp.com/biz/sixth-st-tavern-los-angeles?start=540
# https://www.yelp.com/biz/heres-looking-at-you-los-angeles?start=0
# https://www.yelp.com/biz/heres-looking-at-you-los-angeles?start=20
# https://www.yelp.com/biz/heres-looking-at-you-los-angeles?start=40
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-89a174ceef38> in <module>()
#     191     url='https://www.yelp.com/search?find_desc=American&find_loc=Los+Angeles,+CA'
#     192
# --> 193     run(url)
#     194
#     195
#
# <ipython-input-7-89a174ceef38> in run(url)
#     171             sumReviews=sumReviews+int(Count)
#     172
# --> 173             getHTML(ReviewID,Count)
#     174
#     175
#
# <ipython-input-7-89a174ceef38> in getHTML(ReviewID, Count)
#      71             #Opening a connection and grabbing the page
#      72
# ---> 73         uClient = uReq(my_url)
#      74
#      75         page_html = uClient.read()
#
# /Users/khushalidave/anaconda/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /Users/khushalidave/anaconda/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /Users/khushalidave/anaconda/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /Users/khushalidave/anaconda/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /Users/khushalidave/anaconda/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /Users/khushalidave/anaconda/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 503: Service Unavailable

# %%
#!/usr/bin/python

import os, sys




# Open a file
path = "/Volumes/Khushali Harddisk/YelpDataSet"
dirs = os.listdir( path )

# This would print all the files and directories
for file in dirs:
   print file
